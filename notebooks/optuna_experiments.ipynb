# %% [markdown]
# # Optuna Hyperparameter Optimization for RandomForestRegressor
# This notebook demonstrates how to use Optuna to optimize hyperparameters for a Random Forest model predicting life expectancy based on expenditure data.

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import optuna
from optuna.visualization import plot_optimization_history
# Optional: for matplotlib-based plots
from optuna.visualization.matplotlib import plot_optimization_history as plot_optimization_history_matplotlib

# %% [markdown]
# ## 1. Load and Explore Dataset

# %%
healthexp = sns.load_dataset("healthexp")

healthexp = pd.get_dummies(healthexp)
x = healthexp.drop(['Life_Expectancy'], axis=1)
y = healthexp['Life_Expectancy']

# %% [markdown]
# ## 2. Preprocess Data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=19)

# %% [markdown]
# ## 3. Train Baseline Model

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(random_state = 13)
rfr.fit(x_train, y_train)

y_pred = rfr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mean_absolute_error(y_test, y_pred)
# Out:
# 0.25916363636361917

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.10221141818181628

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9910457602615238

# %% [markdown]
# ## 4. Define Optuna Objective Function

# %%
import optuna
from sklearn.model_selection import cross_val_score

def objective(trial):
    n_stimators = trial.suggest_int('n_estimators', 100, 1000)
    max_depth = trial.suggest_int('max_depth', 10, 50)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 32)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 2, 32)

    model = RandomForestRegressor(n_estimators=n_stimators,
                                    max_depth=max_depth,
                                    min_samples_split=min_samples_split,
                                    min_samples_leaf=min_samples_leaf,
                                    random_state=98)
    
    score = cross_val_score(model, x, y, cv=5, scoring='neg_mean_squared_error', n_jobs=-1).mean()

    return score

# %%
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.RandomSampler(seed=42))
# Out:
# [I 2025-09-04 16:21:34,458] A new study created in memory with name: no-name-11e669cf-1a93-49b8-850b-c4f30bfcf61b

# %% [markdown]
# ## 5. Run Optuna Study

# %%
study.optimize(objective, n_trials=200)
# Out:
# [I 2025-09-04 16:21:40,836] Trial 0 finished with value: -4.553684112850672 and parameters: {'n_estimators': 437, 'max_depth': 48, 'min_samples_split': 24, 'min_samples_leaf': 20}. Best is trial 0 with value: -4.553684112850672.
# [I 2025-09-04 16:21:45,129] Trial 1 finished with value: -5.231423631784025 and parameters: {'n_estimators': 240, 'max_depth': 16, 'min_samples_split': 3, 'min_samples_leaf': 28}. Best is trial 0 with value: -4.553684112850672.
# [I 2025-09-04 16:21:47,160] Trial 2 finished with value: -5.620449440125375 and parameters: {'n_estimators': 641, 'max_depth': 39, 'min_samples_split': 2, 'min_samples_leaf': 32}. Best is trial 0 with value: -4.553684112850672.
# [I 2025-09-04 16:21:49,921] Trial 3 finished with value: -3.3435473286896005 and parameters: {'n_estimators': 850, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 7}. Best is trial 3 with value: -3.3435473286896005.
# [I 2025-09-04 16:21:51,040] Trial 4 finished with value: -3.905587333298098 and parameters: {'n_estimators': 374, 'max_depth': 31, 'min_samples_split': 15, 'min_samples_leaf': 11}. Best is trial 3 with value: -3.3435473286896005.
# [I 2025-09-04 16:21:52,833] Trial 5 finished with value: -3.9083292524054016 and parameters: {'n_estimators': 651, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 13}. Best is trial 3 with value: -3.3435473286896005.
# [I 2025-09-04 16:21:54,212] Trial 6 finished with value: -4.106131739994486 and parameters: {'n_estimators': 510, 'max_depth': 42, 'min_samples_split': 8, 'min_samples_leaf': 17}. Best is trial 3 with value: -3.3435473286896005.
# [I 2025-09-04 16:21:56,068] Trial 7 finished with value: -3.469248293137981 and parameters: {'n_estimators': 633, 'max_depth': 11, 'min_samples_split': 20, 'min_samples_leaf': 7}. Best is trial 3 with value: -3.3435473286896005.
# [I 2025-09-04 16:21:56,703] Trial 8 finished with value: -5.187303937225117 and parameters: {'n_estimators': 158, 'max_depth': 48, 'min_samples_split': 31, 'min_samples_leaf': 27}. Best is trial 3 with value: -3.3435473286896005.
# [I 2025-09-04 16:21:57,710] Trial 9 finished with value: -3.967054263514531 and parameters: {'n_estimators': 374, 'max_depth': 14, 'min_samples_split': 23, 'min_samples_leaf': 15}. Best is trial 3 with value: -3.3435473286896005.
# [I 2025-09-04 16:21:58,265] Trial 10 finished with value: -5.386904237164271 and parameters: {'n_estimators': 209, 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 30}. Best is trial 3 with value: -3.3435473286896005.
# [I 2025-09-04 16:21:59,203] Trial 11 finished with value: -4.218812362472792 and parameters: {'n_estimators': 333, 'max_depth': 37, 'min_samples_split': 11, 'min_samples_leaf': 18}. Best is trial 3 with value: -3.3435473286896005.
# [I 2025-09-04 16:22:00,963] Trial 12 finished with value: -5.099750924020524 and parameters: {'n_estimators': 592, 'max_depth': 17, 'min_samples_split': 32, 'min_samples_leaf': 26}. Best is trial 3 with value: -3.3435473286896005.
# [I 2025-09-04 16:22:03,460] Trial 13 finished with value: -5.374069843976909 and parameters: {'n_estimators': 946, 'max_depth': 46, 'min_samples_split': 20, 'min_samples_leaf': 30}. Best is trial 3 with value: -3.3435473286896005.
# [I 2025-09-04 16:22
. Best is trial 20 with value: -2.538387233411504.
# [I 2025-09-04 16:23:26,828] Trial 65 finished with value: -4.208034345771049 and parameters: {'n_estimators': 654, 'max_depth': 50, 'min_samples_split': 6, 'min_samples_leaf': 18}. Best is trial 20 with value: -2.538387233411504.
# [I 2025-09-04 16:23:29,321] Trial 66 finished with value: -4.9089873536042905 and parameters: {'n_estimators': 890, 'max_depth': 40, 'min_samples_split': 23, 'min_samples_leaf': 23}. Best is trial 20 with value: -2.538387233411504.
# [I 2025-09-04 16:23:30,564] Trial 67 finished with value: -5.146299295250353 and parameters: {'n_estimators': 423, 'max_depth': 22, 'min_samples_split': 27, 'min_samples_leaf': 27}. Best is trial 20 with value: -2.538387233411504.
# [I 2025-09-04 16:23:33,089] Trial 68 finished with value: -4.097933518683618 and parameters: {'n_estimators': 881, 'max_depth': 47, 'min_samples_split': 17, 'min_samples_leaf': 17}. Best is trial 20 with value: -2.538387233411504.
# [I 2025-09-04 16:23:36,101] Trial 69 finished with value: -5.108189845994882 and parameters: {'n_estimators': 819, 'max_depth': 36, 'min_samples_split': 23, 'min_samples_leaf': 26}. Best is trial 20 with value: -2.538387233411504.
# [I 2025-09-04 16:23:38,821] Trial 70 finished with value: -2.721898866073147 and parameters: {'n_estimators': 901, 'max_depth': 23, 'min_samples_split': 13, 'min_samples_leaf': 4}. Best is trial 20 with value: -2.538387233411504.
# [I 2025-09-04 16:23:40,586] Trial 71 finished with value: -4.2139664900044735 and parameters: {'n_estimators': 621, 'max_depth': 11, 'min_samples_split': 16, 'min_samples_leaf': 18}. Best is trial 20 with value: -2.538387233411504.
# [I 2025-09-04 16:23:41,706] Trial 72 finished with value: -2.119059793034978 and parameters: {'n_estimators': 358, 'max_depth': 34, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 72 with value: -2.119059793034978.
# [I 2025-09-04 16:23:44,351] Trial 73 finished with value: -4.217941694813395 and parameters: {'n_estimators': 841, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 18}. Best is trial 72 with value: -2.119059793034978.
# [I 2025-09-04 16:23:46,629] Trial 74 finished with value: -3.088336874016731 and parameters: {'n_estimators': 793, 'max_depth': 18, 'min_samples_split': 21, 'min_samples_leaf': 4}. Best is trial 72 with value: -2.119059793034978.
# [I 2025-09-04 16:23:47,356] Trial 75 finished with value: -4.665147856331805 and parameters: {'n_estimators': 146, 'max_depth': 31, 'min_samples_split': 18, 'min_samples_leaf': 21}. Best is trial 72 with value: -2.119059793034978.
# [I 2025-09-04 16:23:49,585] Trial 76 finished with value: -3.8932357515047498 and parameters: {'n_estimators': 754, 'max_depth': 50, 'min_samples_split': 18, 'min_samples_leaf': 12}. Best is trial 72 with value: -2.119059793034978.
# [I 2025-09-04 16:23:52,161] Trial 77 finished with value: -2.8110253137217245 and parameters: {'n_estimators': 816, 'max_depth': 21, 'min_samples_split': 15, 'min_samples_leaf': 4}. Best is trial 72 with value: -2.119059793034978.
# [I 2025-09-04 16:23:52,536] Trial 78 finished with value: -4.874940354907325 and parameters: {'n_estimators': 122, 'max_depth': 49, 'min_samples_split': 27, 'min_samples_leaf': 23}. Best is trial 72 with value: -2.119059793034978.
# [I 2025-09-04 16:23:54,154] Trial 79 finished with value: -3.787510384412407 and parameters: {'n_estimators': 468, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 9}. Best is trial 72 with value: -2.119059793034978.
# [I 2025-09-04 16:23:56,065] Trial 80 finished with value: -3.9017984358495226 and parameters: {'n_estimators': 594, 'max_depth': 39, 'min_samples_split': 22, 'min_samples_leaf': 10}. Best is trial 72 with value: -2.119059793034978.
# [I 2025-09-04 16:23:58,824] Trial 81 finished with value: -4.5322151676771405 and parameters: {'n_estimators': 960, 'max_depth': 40, 'min_samples_split': 19, 'min_samples_leaf': 20}. Best is trial 72 with value: -2.119059793034978.
# [I 2025-09-04 16:24:00,174] Trial 82 finished with value: -5.060586774480407 and parameters: {'n_estimators': 478, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 25}. Best is trial 72 with value: -2.119059793034978.
# [I 2025-09-04 16:24:00,603] Trial 83 finished with value: -2.127411302723749 and parameters: {'n_estimators': 112, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 72 with value: -2.119059793034978.
# [I 2025-09-04 16:24:03,354] Trial 84 finished with value: -2.9730319546064328 and parameters: {'n_estimators': 870, 'max_depth': 38, 'min_samples_split': 16, 'min_samples_leaf': 5}. Best is trial 72 with value: -2.119059793034978.

# %% [markdown]
# ## 6. Visualize Optimization Results

# %%
import sys
print(sys.executable)

import plotly
print(plotly.__version__)
# Out:
# c:\Users\patrick\Documents\Optuna\.venv\Scripts\python.exe
# 6.3.0

# %%
import optuna.visualization
optuna.visualization.plot_optimization_history
# Out:
# <function optuna.visualization._optimization_history.plot_optimization_history(study: 'Study | Sequence[Study]', *, target: 'Callable[[FrozenTrial], float] | None' = None, target_name: 'str' = 'Objective Value', error_bar: 'bool' = False) -> "'go.Figure'">

# %%
best_params = study.best_params

print(plotly.__version__)

optuna.visualization.plot_optimization_history(study)
# Out:
# 6.3.0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\patrick\Documents\Optuna\.venv\Lib\site-packages\optuna\visualization\_plotly_imports.py:7
#       6 with try_import() as _imports:
# ----> 7     import plotly
#       8     from plotly import __version__ as plotly_version
#
# ModuleNotFoundError: No module named 'plotly'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[65], line 5
#       1 best_params = study.best_params
#       3 print(plotly.__version__)
# ----> 5 optuna.visualization.plot_optimization_history(study)
#
# File c:\Users\patrick\Documents\Optuna\.venv\Lib\site-packages\optuna\visualization\_optimization_history.py:200, in plot_optimization_history(study, target, target_name, error_bar)
#     172 def plot_optimization_history(
#     173     study: Study | Sequence[Study],
#     174     *,
#    (...)    177     error_bar: bool = False,
#     178 ) -> "go.Figure":
#     179     """Plot optimization history of all trials in a study.
#     180
#     181     Args:
#    (...)    197         A :class:`plotly.graph_objects.Figure` object.
#     198     """
# --> 200     _imports.check()
#     202     info_list = _get_optimization_history_info_list(study, target, target_name, error_bar)
#     203     return _get_optimization_history_plot(info_list, target_name)
#
# File c:\Users\patrick\Documents\Optuna\.venv\Lib\site-packages\optuna\_imports.py:97, in _DeferredImportExceptionContextManager.check(self)
#      95 if self._deferred is not None:
#      96     exc_value, message = self._deferred
# ---> 97     raise ImportError(message) from exc_value
#
# ImportError: Tried to import 'plotly' but failed. Please make sure that the package is installed correctly to use this feature. Actual error: No module named 'plotly'.

# %%
optuna.visualization.plot_parallel_coordinate(study)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\patrick\Documents\Optuna\.venv\Lib\site-packages\optuna\visualization\_plotly_imports.py:7
#       6 with try_import() as _imports:
# ----> 7     import plotly
#       8     from plotly import __version__ as plotly_version
#
# ModuleNotFoundError: No module named 'plotly'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 optuna.visualization.plot_parallel_coordinate(study)
#
# File c:\Users\patrick\Documents\Optuna\.venv\Lib\site-packages\optuna\visualization\_parallel_coordinate.py:83, in plot_parallel_coordinate(study, params, target, target_name)
#      50 def plot_parallel_coordinate(
#      51     study: Study,
#      52     params: list[str] | None = None,
#    (...)     55     target_name: str = "Objective Value",
#      56 ) -> "go.Figure":
#      57     """Plot the high-dimensional parameter relationships in a study.
#      58
#      59     Note that, if a parameter contains missing values, a trial with missing values is not plotted.
#    (...)     80         of :class:`~optuna.study.Study` is ``minimize``.
#      81     """
# ---> 83     _imports.check()
#      84     info = _get_parallel_coordinate_info(study, params, target, target_name)
#      85     return _get_parallel_coordinate_plot(info)
#
# File c:\Users\patrick\Documents\Optuna\.venv\Lib\site-packages\optuna\_imports.py:97, in _DeferredImportExceptionContextManager.check(self)
#      95 if self._deferred is not None:
#      96     exc_value, message = self._deferred
# ---> 97     raise ImportError(message) from exc_value
#
# ImportError: Tried to import 'plotly' but failed. Please make sure that the package is installed correctly to use this feature. Actual error: No module named 'plotly'.

# %% [markdown]
# ## 7. Evaluate Best Model

# %%
best_n_estimators = best_params['n_estimators']
best_max_depth = best_params['max_depth']
best_min_samples_split = best_params['min_samples_split']
best_min_samples_leaf = best_params['min_samples_leaf']

# %%
best_model = RandomForestRegressor(n_estimators=study.best_params['n_estimators'],
                                    max_depth=study.best_params['max_depth'],   
                                    min_samples_split=study.best_params['min_samples_split'],
                                    min_samples_leaf=study.best_params['min_samples_leaf'])

best_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=45, min_samples_leaf=2, min_samples_split=3,
#                       n_estimators=940)

# %%
y_pred = best_model.predict(x_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 0.3105838311269472

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.13930985317088607

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9877957487977996
